# %% [markdown]
# <a href="https://colab.research.google.com/github/dpetrovic89/Forecast-Salaries-for-end-of-2020-and-2021-in-Serbia/blob/main/Forecast_Salaries_for_end_of_2020_and_2021_in_Serbia_%5BExploration%5D_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1 **Define Goal**: Predict Salaries for end of 2020 and 2021 in Serbia.
#
# **Data Source**: https://data.stat.gov.rs/Home/Result/2403040101?languageCode=sr-Cyrl&displayMode=table&guid=1f45011f-8535-44ac-bdcd-a35a3ddfec6e

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Zarade.csv')
df
# Out:
#            Date   Neto  Bruto
# 0    1977-01-31   3520      0
# 1    1977-02-28   3604      0
# 2    1977-03-31   3971      0
# 3    1977-04-30   3925      0
# 4    1977-05-31   3959      0
# ..          ...    ...    ...
# 520  2020-05-31  58892  81464
# 521  2020-06-30  59740  82572
# 522  2020-07-31  60029  83016
# 523  2020-08-31  58513  80901
# 524  2020-09-30  59698  82515
#
# [525 rows x 3 columns]

# %% [markdown]
# # Explore Data

# %%
# First 5 Rows

# Ne postoje podaci za Bruto pre 1992 godine
df.head()
# Out:
#          Date  Neto  Bruto
# 0  1977-01-31  3520      0
# 1  1977-02-28  3604      0
# 2  1977-03-31  3971      0
# 3  1977-04-30  3925      0
# 4  1977-05-31  3959      0

# %%
# Last 5 Rows
df.tail()
# Out:
#            Date   Neto  Bruto
# 520  2020-05-31  58892  81464
# 521  2020-06-30  59740  82572
# 522  2020-07-31  60029  83016
# 523  2020-08-31  58513  80901
# 524  2020-09-30  59698  82515

# %%
# 525 Rows and 3 Columns
df.shape
# Out:
# (525, 3)

# %%
pd.set_option('float_format', '{:f}'.format)

df.describe()
# Out:
#                   Neto            Bruto
# count       525.000000       525.000000
# mean     506201.114286    569636.748571
# std     6104856.557979  11059876.737485
# min          25.000000         0.000000
# 25%        5797.000000         0.000000
# 50%       20094.000000      5277.000000
# 75%       44630.000000     51115.000000
# max   133999365.000000 252832588.000000

# %% [markdown]
# Dosta cudnih podataka zbog hiperinflacije.
#
#
# ---
#
#
# **Najveca Neto Plata** 133.999.365 Novembar 1993
#
# **Najveca Bruto Plata** 252.832.588 Novembar 1993
#
#
# ---
# Novi dinar: https://www.blic.rs/biznis/kako-je-ovaj-super-deka-1994-uveo-novi-dinar-i-razbio-dve-zablude-o-srpskoj-ekonomiji/le75t4q
#
# **Najmanja Neto Plata** 25 Dinara je bila u Januaru 1994

# %% [markdown]
# # Visualize data

# %%
import plotly.express as px

# %%
fig = px.line(df, x="Date", y="Neto", title='Neto Zarada od 1977 do 2020 sa hiperinflacijama 1989 i `1993')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fe7d4d26-feef-446a-9e67-d1944e1852ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fe7d4d26-feef-446a-9e67-d1944e1852ab")) {
#                     Plotly.newPlot(
#                         'fe7d4d26-feef-446a-9e67-d1944e1852ab',
# ...

# %% [markdown]
# podaci iz 1993 su veliki da bi mogli da vidimo i razmemo ostale godine
#
# smanjicemo **tabelu = dataframe** od 1994 do 2020

# %%
display(df.iloc[204:, :])
# Out:
#            Date   Neto  Bruto
# 204  1994-01-31     25     45
# 205  1994-02-28     64    122
# 206  1994-03-31     82    151
# 207  1994-04-30    116    213
# 208  1994-05-31    136    233
# ..          ...    ...    ...
# 520  2020-05-31  58892  81464
# 521  2020-06-30  59740  82572
# 522  2020-07-31  60029  83016
# 523  2020-08-31  58513  80901
# 524  2020-09-30  59698  82515
#
# [321 rows x 3 columns]

# %%
df1 = df.iloc[204:, :]

df1
# Out:
#            Date   Neto  Bruto
# 204  1994-01-31     25     45
# 205  1994-02-28     64    122
# 206  1994-03-31     82    151
# 207  1994-04-30    116    213
# 208  1994-05-31    136    233
# ..          ...    ...    ...
# 520  2020-05-31  58892  81464
# 521  2020-06-30  59740  82572
# 522  2020-07-31  60029  83016
# 523  2020-08-31  58513  80901
# 524  2020-09-30  59698  82515
#
# [321 rows x 3 columns]

# %%
fig = px.line(df1, x="Date", y="Neto", title='Neto Zarada od 1994 do 2020')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="54c383f7-e913-4858-af0b-5d417a43b3f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("54c383f7-e913-4858-af0b-5d417a43b3f7")) {
#                     Plotly.newPlot(
#                         '54c383f7-e913-4858-af0b-5d417a43b3f7',
# ...

# %%
df_long=pd.melt(df1, id_vars=['Date'], value_vars=['Neto', 'Bruto'])

# plotly 
fig = px.line(df_long, x='Date', y='value', color='variable', title='Neto i Bruto Zarada od 1994 do 2020')

# Show plot 
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e23b3f8b-4af8-4225-986e-c99636b429b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e23b3f8b-4af8-4225-986e-c99636b429b9")) {
#                     Plotly.newPlot(
#                         'e23b3f8b-4af8-4225-986e-c99636b429b9',
# ...

# %% [markdown]
# # Apply Forecasting Methods
#
# continue at: https://colab.research.google.com/drive/1_8q62qCvcCUxYwk8rAoqvHxFPkiJC0_s#scrollTo=f6ciXAU0exkP
